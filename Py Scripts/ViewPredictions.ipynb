# %%
import matplotlib.pyplot as plt
import os
import pandas as pd

# %%
os.chdir('/content/')

# %%
files = sorted([i for i in os.listdir() if i.split('.')[1] == 'csv'])
for i, file in enumerate(files):
  print(i, file)
file_number = int(input('From the above list, enter the index of Stock whose predictions you want to view:\n'))

curr_file = open(files[file_number], 'r', newline='')
# Out:
# 0 ADANIPORTS.csv
# 1 ASIANPAINT.csv
# 2 AXISBANK.csv
# 3 BAJAJ-AUTO.csv
# 4 BAJFINANCE.csv
# 5 BHARTIARTL.csv
# 6 BPCL.csv
# 7 CIPLA.csv
# 8 COALINDIA.csv
# 9 DRREDDY.csv
# 10 GAIL.csv
# 11 GRASIM.csv
# 12 HCLTECH.csv
# 13 HDFC.csv
# 14 HDFCBANK.csv
# 15 HEROMOTOCO.csv
# 16 HINDALCO.csv
# 17 HINDPETRO.csv
# 18 HINDUNILVR.csv
# 19 IBULHSGFIN.csv
# 20 ICICIBANK.csv
# 21 INDUSINDBK.csv
# 22 INFY.csv
# 23 IOC.csv
# 24 ITC.csv
# 25 JSWSTEEL.csv
# 26 KOTAKBANK.csv
# 27 LT.csv
# 28 M.csv
# 29 MARUTI.csv
# 30 NTPC.csv
# 31 ONGC.csv
# 32 PNB.csv
# 33 POWERGRID.csv
# 34 RELIANCE.csv
# 35 SBIN.csv
# 36 SUNPHARMA.csv
# 37 TATAMOTORS.csv
# 38 TATASTEEL.csv
# 39 TCS.csv
# 40 TECHM.csv
# 41 TITAN.csv
# 42 ULTRACEMCO.csv
# 43 UPL.csv
# 44 VEDL.csv
# 45 WIPRO.csv
# 46 YESBANK.csv
# 47 ZEEL.csv
# From the above list, enter the index of Stock whose predictions you want to view:
# 35

# %%
df = pd.read_csv(curr_file)

df
# Out:
#       Real Price       LSTM  ...  Random Forest  Gradient Boosting
# 0         368.95  351.10940  ...     366.468316         365.925441
# 1         368.15  351.46075  ...     366.543332         365.990147
# 2         365.95  350.99258  ...     366.088888         365.469221
# 3         365.70  345.83870  ...     366.750985         367.951663
# 4         365.80  345.69750  ...     364.903855         365.590126
# ...          ...        ...  ...            ...                ...
# 1408      335.20  338.28656  ...     335.278754         335.241871
# 1409      335.25  338.35657  ...     334.705082         335.330764
# 1410      334.40  338.37408  ...     334.801117         335.330764
# 1411      333.80  337.91852  ...     333.905276         334.532174
# 1412      333.80  337.70640  ...     335.605997         333.956109
#
# [1413 rows x 7 columns]

# %% [markdown]
# ### LSTM

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Real Price'], color='red', label='Real Prices')
plt.plot(df['LSTM'], color='blue', label='Predicted Prices(LSTM)')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# ### SVR - Linear

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Real Price'], color='red', label='Real Prices')
plt.plot(df['SVR_Linear'], color='blue', label='Predicted Prices(SVR - Linear)')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# ### SVR - Polynomial

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Real Price'], color='red', label='Real Prices')
plt.plot(df['SVR_Polynomial'], color='blue', label='Predicted Prices(SVR - Polynomial)')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# ### SVR - Rbf

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Real Price'], color='red', label='Real Prices')
plt.plot(df['SVR_Rbf'], color='blue', label='Predicted Prices(SVR - Rbf)')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# ### Random Forest Regressor

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Real Price'], color='red', label='Real Prices')
plt.plot(df['Random Forest'], color='blue', label='Predicted Prices(Random Forest Regressor)')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend()
plt.show()

# %% [markdown]
# #### Gradient Boosting Regressor

# %%
plt.figure(figsize=(12, 8))
plt.plot(df['Real Price'], color='red', label='Real Prices')
plt.plot(df['Gradient Boosting'], color='blue', label='Predicted Prices(Gradient Boosting Regressor)')
plt.xlabel('Time')
plt.ylabel('Close Price')
plt.legend()
plt.show()
